# %%
# !pip install --upgrade huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (0.14.1)
# Requirement already satisfied: filelock in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (3.12.0)
# Requirement already satisfied: fsspec in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (2023.5.0)
# Requirement already satisfied: requests in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (2.28.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: colorama in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub) (2022.12.7)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install -qq -U diffusers transformers

# %%
# !pip install --upgrade accelerate
# Out:
# Requirement already satisfied: accelerate in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (0.19.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: filelock in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->accelerate) (3.12.0)
# Requirement already satisfied: typing-extensions in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\navami\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)

# %%
from diffusers import StableDiffusionPipeline
pipe = StableDiffusionPipeline.from_pretrained('SG161222/Realistic_Vision_V1.4').to('cuda')
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 from diffusers import StableDiffusionPipeline
# ----> 2 pipe = StableDiffusionPipeline.from_pretrained('SG161222/Realistic_Vision_V1.4').to('cuda')
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:670, in DiffusionPipeline.to(self, torch_device, torch_dtype, silence_dtype_warnings)
#     666     logger.warning(
#     667         f"The module '{module.__class__.__name__}' has been loaded in 8bit and moving it to {torch_dtype} via `.to()` is not yet supported. Module is still on {module.device}."
#     668     )
#     669 else:
# --> 670     module.to(torch_device, torch_dtype)
#     672 if (
#     673     module.dtype == torch.float16
#     674     and str(torch_device) in ["cpu"]
#     675     and not silence_dtype_warnings
#     676     and not is_offloaded
#     677 ):
#     678     logger.warning(
#     679         "Pipelines loaded with `torch_dtype=torch.float16` cannot run with `cpu` device. It"
#     680         " is not recommended to move them to `cpu` as running them will fail. Please make"
#    (...)
#     683         " `torch_dtype=torch.float16` argument, or use another device for inference."
#     684     )
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:1878, in PreTrainedModel.to(self, *args, **kwargs)
#    1873     raise ValueError(
#    1874         "`.to` is not supported for `8-bit` models. Please use the model as it is, since the"
#    1875         " model has already been set to the correct devices and casted to the correct `dtype`."
#    1876     )
#    1877 else:
# -> 1878     return super().to(*args, **kwargs)
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 797 (1 times)]
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File c:\Users\NAVAMI\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:239, in _lazy_init()
#     235     raise RuntimeError(
#     236         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     237         "multiprocessing, you must use the 'spawn' start method")
#     238 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 239     raise AssertionError("Torch not compiled with CUDA enabled")
#     240 if _cudart is None:
#     241     raise AssertionError(
#     242         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
import torch
torch.cuda.empty_cache()
# Initialize a prompt
prompt = "a cartoon of an indian student"

# Pass the prompt in the pipeline
pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       4 prompt = "a cartoon of an indian student"
#       6 # Pass the prompt in the pipeline
# ----> 7 pipe(prompt).images[0]
#
# NameError: name 'pipe' is not defined
